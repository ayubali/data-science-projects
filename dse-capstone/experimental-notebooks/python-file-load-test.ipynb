# %%
import signal_utll
import matplotlib.pyplot as plt

# %%
X, Y, top_peaks = signal_utll.find_top_peaks('../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A_1.mat', 0.4, 3.5, 1.65, 0.7, 5)

# %%
plt.figure(figsize=(12, 6), dpi=80)
plt.plot(Y)
plt.plot(top_peaks, Y[top_peaks], "x")
plt.show()
