# %%
import scipy.io as sio
from scipy.fft import fft
import os,glob
import math
import numpy as np
import pandas as pd
import os,glob
import pyexcel

# %%
df1 = pd.read_csv('../../datasets/ds_hr_0.8_2.5hz.csv')
df2 = pd.read_csv('../../datasets/ds_0_07Hz.csv')
df3 = pd.read_csv('../../datasets/ds_26_10Hz.csv')
df4 = pd.read_csv('../../datasets/ds_21_30Hz.csv')
df5 = pd.read_csv('../../datasets/ds_31_40Hz.csv')
df6 = pd.read_csv('../../datasets/ds_41_50hz.csv')

df7 = pd.read_csv('../../datasets/ds_rms.csv')
df8 = pd.read_csv('../../datasets/ds_zero_crossing_rate.csv')
df9 = pd.read_csv('../../datasets/ds_spectral_flatness.csv')
df10 = pd.read_csv('../../datasets/ds_spectral_rolloff.csv')
df11 = pd.read_csv('../../datasets/ds_spectral_centroid.csv')
df12 = pd.read_csv('../../datasets/ds_poly_features.csv')
df13 = pd.read_csv('../../datasets/ds_spectral_bandwidth.csv')


df1 = df1.join(df2['Peak Hz in 0~0.7hz']).join(df3['Peak Hz in 2.6~10hz'])
df1 = df1.join(df4['Peak Hz in 21~30hz']).join(df5['Peak Hz in 31~40hz']).join(df6['Peak Hz in 41~50hz'])

df1 = df1.join(df7['RMS avg']).join(df8['Zero crossing rate avg']).join(df9['Spectral flatness avg'])
df1 = df1.join(df10['Spectral rolloff avg']).join(df11['Spectral centroid avg'])
df1 = df1.join(df12['Poly features avg']).join(df13['Spectral bandwidth avg'])

# %%
df1.head()
# Out:
#   Age Group     Sex     Sub  Heart Beat 0.8~2.5hz  \
# 0     Age_A  Female  Sub 25                 53.54
# 1     Age_A  Female  Sub 28                 56.82
# 2     Age_A  Female  Sub 32                 52.78
# 3     Age_A  Female  Sub 35                 53.81
# 4     Age_A  Female  Sub 44                 69.73
#
#    Heart Beat 0.8~2.5hz from Avg  Peak Hz in 0~0.7hz  Peak Hz in 2.6~10hz  \
# 0                           69.0                 0.0                 5.50
# 1                           78.0                 0.0                 3.12
# 2                           78.0                 0.0                 3.00
# 3                           76.0                 0.0                 4.00
# 4                           83.0                 0.0                 5.78
#
#    Peak Hz in 21~30hz  Peak Hz in 31~40hz  Peak Hz in 41~50hz  RMS avg  \
# 0               23.33               31.00               43.67   0.2528
# 1               30.00               40.00               43.25   0.1949
# ...

# %%
df1
# Out:
#    Age Group     Sex     Sub  Heart Beat 0.8~2.5hz  \
# 0      Age_A  Female  Sub 25                 53.54
# 1      Age_A  Female  Sub 28                 56.82
# 2      Age_A  Female  Sub 32                 52.78
# 3      Age_A  Female  Sub 35                 53.81
# 4      Age_A  Female  Sub 44                 69.73
# 5      Age_A  Female  Sub 46                 55.91
# 6      Age_A  Female  Sub 63                 55.67
# 7      Age_A  Female  Sub 64                109.22
# 8      Age_A  Female  Sub 66                 87.67
# 9      Age_A  Female  Sub 69                 51.43
# 10     Age_A  Female  Sub 70                 79.64
# 11     Age_A  Female  Sub 72                 75.44
# 12     Age_A  Female  Sub 73                 73.57
# 13     Age_A  Female  Sub 74                 77.20
# 14     Age_A  Female   Sub 8                 56.79
# 15     Age_A  Female  sub 59                 64.50
# 16     Age_A    Male  Sub 36                 55.38
# ...

# %%
df1.to_csv('../../datasets/ds_hr_with_hz.csv',index = False, header=True)

# %%
df1.shape
# Out:
# (40, 17)
