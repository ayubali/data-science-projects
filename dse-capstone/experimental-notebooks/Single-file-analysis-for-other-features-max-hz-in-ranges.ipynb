# %%
import scipy.io as sio
from scipy.fft import fft
import os,glob
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mat4py import loadmat
import signal_utll
import heapq

# %%
Hz_Lthr, Hz_Hthr, number_of_elements = 0, 0.7, 5
file = '../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A_1.mat'
[X,y] =  signal_utll.wfft_hz(file, Hz_Lthr, Hz_Hthr)
# remove the trend
Y = signal_utll.remove_trends_from_signal(X,y)
peaks, _ = signal_utll.find_peaks(Y, height=0)

top_ten_peaks = heapq.nlargest(number_of_elements, Y[peaks])

top_ten_peaks_index = [index[0] for index in [np.where(Y == peak)[0] for peak in top_ten_peaks]]
top_ten_peaks_index.sort()


plt.figure(figsize=(12, 6), dpi=80)
plt.plot(Y)
plt.plot(top_ten_peaks_index, Y[top_ten_peaks_index], "x")
plt.show()

# %%
Hz_Lthr, Hz_Hthr, number_of_elements = 0.8, 2.5, 5
[X,y] =  signal_utll.wfft_hz(file, Hz_Lthr, Hz_Hthr)
# remove the trend
Y = signal_utll.remove_trends_from_signal(X,y)
peaks, _ = signal_utll.find_peaks(Y, height=0)

top_ten_peaks = heapq.nlargest(number_of_elements, Y[peaks])

top_ten_peaks_index = [index[0] for index in [np.where(Y == peak)[0] for peak in top_ten_peaks]]
top_ten_peaks_index.sort()


plt.figure(figsize=(12, 6), dpi=80)
plt.plot(Y)
plt.plot(top_ten_peaks_index, Y[top_ten_peaks_index], "x")
plt.show()

# %%
Hz_Lthr, Hz_Hthr, number_of_elements = 2.6, 10, 5
[X,y] =  signal_utll.wfft_hz(file, Hz_Lthr, Hz_Hthr)
# remove the trend
Y = signal_utll.remove_trends_from_signal(X,y)
peaks, _ = signal_utll.find_peaks(Y, height=0)

top_ten_peaks = heapq.nlargest(number_of_elements, Y[peaks])

top_ten_peaks_index = [index[0] for index in [np.where(Y == peak)[0] for peak in top_ten_peaks]]
top_ten_peaks_index.sort()


plt.figure(figsize=(12, 6), dpi=80)
plt.plot(Y)
plt.plot(top_ten_peaks_index, Y[top_ten_peaks_index], "x")
plt.show()

# %%
Hz_Lthr, Hz_Hthr, number_of_elements =  11, 20, 5
[X,y] =  signal_utll.wfft_hz(file, Hz_Lthr, Hz_Hthr)
# remove the trend
Y = signal_utll.remove_trends_from_signal(X,y)
peaks, _ = signal_utll.find_peaks(Y, height=0)

top_ten_peaks = heapq.nlargest(number_of_elements, Y[peaks])

top_ten_peaks_index = [index[0] for index in [np.where(Y == peak)[0] for peak in top_ten_peaks]]
top_ten_peaks_index.sort()

plt.figure(figsize=(12, 6), dpi=80)
plt.plot(Y)
plt.plot(top_ten_peaks_index, Y[top_ten_peaks_index], "x")
plt.show()

# %%
Hz_Lthr, Hz_Hthr, number_of_elements =  21, 30, 5
[X,y] =  signal_utll.wfft_hz(file, Hz_Lthr, Hz_Hthr)
# remove the trend
Y = signal_utll.remove_trends_from_signal(X,y)
peaks, _ = signal_utll.find_peaks(Y, height=0)

top_ten_peaks = heapq.nlargest(number_of_elements, Y[peaks])

top_ten_peaks_index = [index[0] for index in [np.where(Y == peak)[0] for peak in top_ten_peaks]]
top_ten_peaks_index.sort()


plt.figure(figsize=(12, 6), dpi=80)
plt.plot(Y)
plt.plot(top_ten_peaks_index, Y[top_ten_peaks_index], "x")
plt.show()

# %%
Hz_Lthr, Hz_Hthr, number_of_elements =  31, 40, 5
[X,y] =  signal_utll.wfft_hz(file, Hz_Lthr, Hz_Hthr)
# remove the trend
Y = signal_utll.remove_trends_from_signal(X,y)
peaks, _ = signal_utll.find_peaks(Y, height=0)

top_ten_peaks = heapq.nlargest(number_of_elements, Y[peaks])

top_ten_peaks_index = [index[0] for index in [np.where(Y == peak)[0] for peak in top_ten_peaks]]
top_ten_peaks_index.sort()


plt.figure(figsize=(12, 6), dpi=80)
plt.plot(Y)
plt.plot(top_ten_peaks_index, Y[top_ten_peaks_index], "x")
plt.show()

# %%
Hz_Lthr, Hz_Hthr, number_of_elements =  41, 50, 5
[X,y] =  signal_utll.wfft_hz(file, Hz_Lthr, Hz_Hthr)
# remove the trend
Y = signal_utll.remove_trends_from_signal(X,y)
peaks, _ = signal_utll.find_peaks(Y, height=0)

top_ten_peaks = heapq.nlargest(number_of_elements, Y[peaks])

top_ten_peaks_index = [index[0] for index in [np.where(Y == peak)[0] for peak in top_ten_peaks]]
top_ten_peaks_index.sort()


plt.figure(figsize=(12, 6), dpi=80)
plt.plot(Y)
plt.plot(top_ten_peaks_index, Y[top_ten_peaks_index], "x")
plt.show()

# %%
def find_peaks(file, Hz_Lthr, Hz_Hthr, no_peaks):
    [X,y] = signal_utll.wfft_hz(file, Hz_Lthr, Hz_Hthr)
    Y = signal_utll.remove_trends_from_signal(X,y)
    peaks, _ = signal_utll.find_peaks(Y, height=0)
    top_peaks = heapq.nlargest(no_peaks, Y[peaks])
    top_peaks_index = [index[0] for index in [np.where(Y == peak)[0] for peak in top_peaks]]
    top_peaks_index.sort()
    hz_peaks = [round(X[peak]) for peak in top_peaks_index]
    return hz_peaks

# %%
files_25 = ['../datasets/Age_A/Age_A_Female/Sub 25/25Neck_L_A_1.mat',
        '../datasets/Age_A/Age_A_Female/Sub 25/25Neck_L_A_2.mat',
        '../datasets/Age_A/Age_A_Female/Sub 25/25Neck_L_A_3.mat',
        '../datasets/Age_A/Age_A_Female/Sub 25/25Neck_R_A_1.mat',
        '../datasets/Age_A/Age_A_Female/Sub 25/25Neck_R_A_2.mat',
        '../datasets/Age_A/Age_A_Female/Sub 25/25Neck_R_A_3.mat']

all_peaks_hr = []
Hz_Lthr, Hz_Hthr, no_peaks = 2.6, 10, 5
for  file in files_25:
    hr_on_peaks = find_peaks(file, Hz_Lthr, Hz_Hthr, no_peaks)
    all_peaks_hr.append(hr_on_peaks)
    print(hr_on_peaks)
# Out:
# [4.0, 4.0, 5.0, 5.0, 6.0]
# [5.0, 6.0, 6.0, 6.0, 7.0]
# [3.0, 4.0, 5.0, 10.0, 10.0]
# [7.0, 7.0, 7.0, 8.0, 8.0]
# [7.0, 9.0, 9.0, 10.0, 10.0]
# [3.0, 3.0, 9.0, 9.0, 9.0]

# %%
flat_list = [item for sublist in all_peaks_hr for item in sublist]

# %%
center_peak  = signal_utll.do_clusters_and_find_max_center(flat_list, 5)

# %%
import kmeans1d
from collections import Counter
clusters, centroids = kmeans1d.cluster(flat_list, 5)
counter = Counter(clusters)

# %%
counter
# Out:
# Counter({0: 6, 1: 8, 2: 5, 4: 4, 3: 7})

# %%
counter.values()
# Out:
# dict_values([6, 8, 5, 4, 7])

# %%
import matplotlib.pyplot as plt
centers = ['center 0', 'center 1', 'center 2', 'center 3', 'center 4']
x_pos = [i for i, _ in enumerate(centers)]
plt.bar(counter.keys(), counter.values(), align='center', alpha=0.5)
plt.xticks(x_pos, centers)
plt.ylabel('Neighbors')
plt.xlabel('Cluster Center')
plt.title('Cluster Vs Neigbor count')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(flat_list, '*', color=[0.5, 0.5, 0.5]) # Gray stars
plt.plot(centroids, '*', color=[1.0, 0.0, 0.0]) # Gray stars
plt.title('Cluster centers and neigbors')
plt.show()

# %%
counter
# Out:
# Counter({0: 6, 1: 8, 2: 5, 4: 4, 3: 7})

# %%
centroids
# Out:
# [3.5, 5.5, 7.0, 8.714285714285714, 10.0]

# %%
print('The center with max neigbor {} hz'.format( centroids[1]))
# Out:
# The center with max neigbor 5.5 hz

# %%
files_36 = ['../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A_1.mat',
        '../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A_2.mat',
        '../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A_3.mat',
        '../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A_1.mat',
        '../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A_2.mat',
        '../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A_3.mat']
all_peaks_hr = []
Hz_Lthr, Hz_Hthr, no_peaks = 2.6, 10, 5
for  file in files_25:
    hr_on_peaks = find_peaks(file, Hz_Lthr, Hz_Hthr, no_peaks)
    all_peaks_hr.append(hr_on_peaks)
    print(hr_on_peaks)

flat_list = [item for sublist in all_peaks_hr for item in sublist]
center_peak  = signal_utll.do_clusters_and_find_max_center(flat_list, 5)

clusters, centroids = kmeans1d.cluster(flat_list, 5)
counter = Counter(clusters)
# Out:
# [4.0, 4.0, 5.0, 5.0, 6.0]
# [5.0, 6.0, 6.0, 6.0, 7.0]
# [3.0, 4.0, 5.0, 10.0, 10.0]
# [7.0, 7.0, 7.0, 8.0, 8.0]
# [7.0, 9.0, 9.0, 10.0, 10.0]
# [3.0, 3.0, 9.0, 9.0, 9.0]

# %%
import matplotlib.pyplot as plt
centers = ['center 0', 'center 1', 'center 2', 'center 3', 'center 4']
x_pos = [i for i, _ in enumerate(centers)]
plt.bar(counter.keys(), counter.values(), align='center', alpha=0.5)
plt.xticks(x_pos, centers)
plt.ylabel('Neighbors')
plt.xlabel('Cluster Center')
plt.title('Cluster Vs Neigbor count')
plt.show()

# %%
max_cluster = signal_utll.find_key_with_maxval(counter)
max_cluster_center_value = centroids.pop(max_cluster[0])

# %%
centers = ['center 0', 'center 1', 'center 2', 'center 3', 'center 4']
plt.plot(flat_list, '*', color=[0.5, 0.5, 0.5]) # Gray stars
plt.plot(centroids, '*', color=[0.0, 1.0, 0.0]) # Gray stars
plt.plot(max_cluster_center_value, '*', color=[1.0, 0.0, 0.0],markersize=12) # Gray stars
plt.title('Cluster centers and neigbors')
plt.show()

# %%
print('The center with max neigbor {} hz'.format(max_cluster_center_value))
# Out:
# The center with max neigbor 5.5 hz
