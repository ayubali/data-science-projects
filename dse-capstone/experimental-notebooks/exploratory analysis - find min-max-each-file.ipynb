# %%
import scipy.io as sio
from scipy.fft import fft
import os,glob
import math
import numpy as np
import pandas as pd
import os,glob
import pyexcel

# %%
from mat4py import loadmat

def get_neck_files(dirname, filepatern):
    files = []
    for filename in glob.iglob(os.path.join(dirname, filepatern), recursive=True):
        files.append(filename)
    return files

def wfft_hz(filename):
    '"Lthr: lower threshold; Hthr: high threshold"'
    data = loadmat(filename)
    fft_data = fft(data['data'])
    NFFT = len(data['data'])
    fft_data = abs(fft_data[0:NFFT])
    f = np.linspace(0, 1, NFFT)
    idx = [i for i, e in enumerate(f)] 
    X=f[idx]
    y=fft_data[idx]
    return X, y

# %%
folder_paths = ['../datasets/Age_A/Age_A_Male/', '../datasets/Age_A/Age_A_Female/']
age_group = []
sex = []
sub = []
side = []
filename = []
pats = ['**/*_R_*.mat', '**/*_L_*.mat']

Hz_Lthr, Hz_Hthr = 0, 10
for folder_path in folder_paths:
    for dirname in glob.iglob(os.path.join(folder_path, '**/')):
        for pat in pats:
            files = get_neck_files(dirname, pat)
            for file in files:
                parts=file.split('/')
                age_group.append(parts[2])
                sex.append(parts[3][6:])
                sub.append(parts[4])
                side.append('Neck'+pat[4:6])
                filename.append(file)
                
data = {
        'Age Group': age_group,
        'Sex': sex,
        'Side': side,
        'Sub': sub,
        'File': filename
       }

# %%
df = pd.DataFrame(data)
df
# Out:
#     Age Group     Sex    Side     Sub  \
# 0       Age_A    Male  Neck_R  Sub 36
# 1       Age_A    Male  Neck_R  Sub 36
# 2       Age_A    Male  Neck_R  Sub 36
# 3       Age_A    Male  Neck_L  Sub 36
# 4       Age_A    Male  Neck_L  Sub 36
# 5       Age_A    Male  Neck_L  Sub 36
# 6       Age_A    Male  Neck_R  Sub 38
# 7       Age_A    Male  Neck_R  Sub 38
# 8       Age_A    Male  Neck_R  Sub 38
# 9       Age_A    Male  Neck_L  Sub 38
# 10      Age_A    Male  Neck_L  Sub 38
# 11      Age_A    Male  Neck_L  Sub 38
# 12      Age_A    Male  Neck_L  Sub 42
# 13      Age_A    Male  Neck_L  Sub 42
# 14      Age_A    Male  Neck_L  Sub 42
# 15      Age_A    Male  Neck_R  Sub 43
# 16      Age_A    Male  Neck_R  Sub 43
# 17      Age_A    Male  Neck_R  Sub 43
# 18      Age_A    Male  Neck_L  Sub 43
# 19      Age_A    Male  Neck_L  Sub 43
# 20      Age_A    Male  Neck_L  Sub 43
# 21      Age_A    Male  Neck_R  Sub 45
# 22      Age_A    Male  Neck_R  Sub 45
# 23      Age_A    Male  Neck_R  Sub 45
# 24      Age_A    Male  Neck_L  Sub 45
# 25      Age_A    Male  Neck_L  Sub 45
# 26      Age_A    Male  Neck_L  Sub 45
# 27      Age_A    Male  Neck_R  Sub 65
# 28      Age_A    Male  Neck_R  Sub 65
# 29      Age_A    Male  Neck_R  Sub 65
# ..        ...     ...     ...     ...
# 139     Age_A  Female  Neck_R  Sub 70
# 140     Age_A  Female  Neck_R  Sub 70
# 141     Age_A  Female  Neck_R  Sub 70
# 142     Age_A  Female  Neck_L  Sub 70
# 143     Age_A  Female  Neck_L  Sub 70
# 144     Age_A  Female  Neck_L  Sub 70
# 145     Age_A  Female  Neck_R  Sub 72
# 146     Age_A  Female  Neck_R  Sub 72
# 147     Age_A  Female  Neck_R  Sub 72
# 148     Age_A  Female  Neck_L  Sub 72
# 149     Age_A  Female  Neck_L  Sub 72
# 150     Age_A  Female  Neck_L  Sub 72
# 151     Age_A  Female  Neck_R  Sub 73
# 152     Age_A  Female  Neck_R  Sub 73
# 153     Age_A  Female  Neck_R  Sub 73
# 154     Age_A  Female  Neck_L  Sub 73
# 155     Age_A  Female  Neck_L  Sub 73
# 156     Age_A  Female  Neck_L  Sub 73
# 157     Age_A  Female  Neck_R  Sub 74
# 158     Age_A  Female  Neck_R  Sub 74
# 159     Age_A  Female  Neck_R  Sub 74
# 160     Age_A  Female  Neck_L  Sub 74
# 161     Age_A  Female  Neck_L  Sub 74
# 162     Age_A  Female  Neck_L  Sub 74
# 163     Age_A  Female  Neck_R   Sub 8
# 164     Age_A  Female  Neck_R   Sub 8
# 165     Age_A  Female  Neck_R   Sub 8
# 166     Age_A  Female  Neck_L   Sub 8
# 167     Age_A  Female  Neck_L   Sub 8
# 168     Age_A  Female  Neck_L   Sub 8
#
#                                                   File
# 0    ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A...
# 1    ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A...
# 2    ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A...
# 3    ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A...
# 4    ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A...
# 5    ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A...
# 6    ../datasets/Age_A/Age_A_Male/Sub 38/38Neck_R_A...
# 7    ../datasets/Age_A/Age_A_Male/Sub 38/38Neck_R_A...
# 8    ../datasets/Age_A/Age_A_Male/Sub 38/38Neck_R_A...
# 9    ../datasets/Age_A/Age_A_Male/Sub 38/38Neck_L_A...
# 10   ../datasets/Age_A/Age_A_Male/Sub 38/38Neck_L_A...
# 11   ../datasets/Age_A/Age_A_Male/Sub 38/38Neck_L_A...
# 12    ../datasets/Age_A/Age_A_Male/Sub 42/42_L_A_1.mat
# 13    ../datasets/Age_A/Age_A_Male/Sub 42/42_L_B_1.mat
# 14    ../datasets/Age_A/Age_A_Male/Sub 42/42_L_C_1.mat
# 15   ../datasets/Age_A/Age_A_Male/Sub 43/43Neck_R_A...
# 16   ../datasets/Age_A/Age_A_Male/Sub 43/43Neck_R_B...
# 17   ../datasets/Age_A/Age_A_Male/Sub 43/43Neck_R_C...
# 18   ../datasets/Age_A/Age_A_Male/Sub 43/43Neck_L_A...
# 19   ../datasets/Age_A/Age_A_Male/Sub 43/43Neck_L_B...
# 20   ../datasets/Age_A/Age_A_Male/Sub 43/43Neck_L_C...
# 21   ../datasets/Age_A/Age_A_Male/Sub 45/45Neck_R_A...
# 22   ../datasets/Age_A/Age_A_Male/Sub 45/45Neck_R_A...
# 23   ../datasets/Age_A/Age_A_Male/Sub 45/45Neck_R_A...
# 24   ../datasets/Age_A/Age_A_Male/Sub 45/45Neck_L_A...
# 25   ../datasets/Age_A/Age_A_Male/Sub 45/45Neck_L_A...
# 26   ../datasets/Age_A/Age_A_Male/Sub 45/45Neck_L_A...
# 27   ../datasets/Age_A/Age_A_Male/Sub 65/65NECK_R_A...
# 28   ../datasets/Age_A/Age_A_Male/Sub 65/65NECK_R_A...
# 29   ../datasets/Age_A/Age_A_Male/Sub 65/65NECK_R_A...
# ..                                                 ...
# 139  ../datasets/Age_A/Age_A_Female/Sub 70/70_neck_...
# 140  ../datasets/Age_A/Age_A_Female/Sub 70/70_neck_...
# 141  ../datasets/Age_A/Age_A_Female/Sub 70/70_neck_...
# 142  ../datasets/Age_A/Age_A_Female/Sub 70/70_neck_...
# 143  ../datasets/Age_A/Age_A_Female/Sub 70/70_neck_...
# 144  ../datasets/Age_A/Age_A_Female/Sub 70/70_neck_...
# 145  ../datasets/Age_A/Age_A_Female/Sub 72/72Neck_R...
# 146  ../datasets/Age_A/Age_A_Female/Sub 72/72Neck_R...
# 147  ../datasets/Age_A/Age_A_Female/Sub 72/72Neck_R...
# 148  ../datasets/Age_A/Age_A_Female/Sub 72/72Neck_L...
# 149  ../datasets/Age_A/Age_A_Female/Sub 72/72Neck_L...
# 150  ../datasets/Age_A/Age_A_Female/Sub 72/72Neck_L...
# 151  ../datasets/Age_A/Age_A_Female/Sub 73/73Neck_R...
# 152  ../datasets/Age_A/Age_A_Female/Sub 73/73Neck_R...
# 153  ../datasets/Age_A/Age_A_Female/Sub 73/73Neck_R...
# 154  ../datasets/Age_A/Age_A_Female/Sub 73/73Neck_L...
# 155  ../datasets/Age_A/Age_A_Female/Sub 73/73Neck_L...
# 156  ../datasets/Age_A/Age_A_Female/Sub 73/73Neck_L...
# 157  ../datasets/Age_A/Age_A_Female/Sub 74/74Neck_R...
# 158  ../datasets/Age_A/Age_A_Female/Sub 74/74Neck_R...
# 159  ../datasets/Age_A/Age_A_Female/Sub 74/74Neck_R...
# 160  ../datasets/Age_A/Age_A_Female/Sub 74/74Neck_L...
# 161  ../datasets/Age_A/Age_A_Female/Sub 74/74Neck_L...
# 162  ../datasets/Age_A/Age_A_Female/Sub 74/74Neck_L...
# 163  ../datasets/Age_A/Age_A_Female/Sub 8/8Neck_R_A...
# 164  ../datasets/Age_A/Age_A_Female/Sub 8/8Neck_R_A...
# 165  ../datasets/Age_A/Age_A_Female/Sub 8/8Neck_R_A...
# 166  ../datasets/Age_A/Age_A_Female/Sub 8/8Neck_L_A...
# 167  ../datasets/Age_A/Age_A_Female/Sub 8/8Neck_L_A...
# 168  ../datasets/Age_A/Age_A_Female/Sub 8/8Neck_L_A...
#
# [169 rows x 5 columns]

# %%
mins=[]
maxs = []
for i, row in df.iterrows():
    [X,y] =  wfft_hz(row['File'])
    mins.append(min(y)[0])
    maxs.append(max(y)[0])

# %%
maxs = [round(x ,3) for x in maxs]

# %%
df['Max fft']= maxs
df['Min fft']= mins

# %%
df
# Out:
#     Age Group     Sex    Side     Sub  \
# 0       Age_A    Male  Neck_R  Sub 36
# 1       Age_A    Male  Neck_R  Sub 36
# 2       Age_A    Male  Neck_R  Sub 36
# 3       Age_A    Male  Neck_L  Sub 36
# 4       Age_A    Male  Neck_L  Sub 36
# 5       Age_A    Male  Neck_L  Sub 36
# 6       Age_A    Male  Neck_R  Sub 38
# 7       Age_A    Male  Neck_R  Sub 38
# 8       Age_A    Male  Neck_R  Sub 38
# 9       Age_A    Male  Neck_L  Sub 38
# 10      Age_A    Male  Neck_L  Sub 38
# 11      Age_A    Male  Neck_L  Sub 38
# 12      Age_A    Male  Neck_L  Sub 42
# 13      Age_A    Male  Neck_R  Sub 43
# 14      Age_A    Male  Neck_L  Sub 43
# 15      Age_A    Male  Neck_R  Sub 45
# 16      Age_A    Male  Neck_R  Sub 45
# 17      Age_A    Male  Neck_R  Sub 45
# 18      Age_A    Male  Neck_L  Sub 45
# 19      Age_A    Male  Neck_L  Sub 45
# 20      Age_A    Male  Neck_L  Sub 45
# 21      Age_A    Male  Neck_R  Sub 65
# 22      Age_A    Male  Neck_R  Sub 65
# 23      Age_A    Male  Neck_R  Sub 65
# 24      Age_A    Male  Neck_L  Sub 65
# 25      Age_A    Male  Neck_L  Sub 65
# 26      Age_A    Male  Neck_L  Sub 65
# 27      Age_A    Male  Neck_R  Sub 67
# 28      Age_A    Male  Neck_R  Sub 67
# 29      Age_A    Male  Neck_R  Sub 67
# ..        ...     ...     ...     ...
# 125     Age_A  Female  Neck_R  Sub 70
# 126     Age_A  Female  Neck_R  Sub 70
# 127     Age_A  Female  Neck_R  Sub 70
# 128     Age_A  Female  Neck_L  Sub 70
# 129     Age_A  Female  Neck_L  Sub 70
# 130     Age_A  Female  Neck_L  Sub 70
# 131     Age_A  Female  Neck_R  Sub 72
# 132     Age_A  Female  Neck_R  Sub 72
# 133     Age_A  Female  Neck_R  Sub 72
# 134     Age_A  Female  Neck_L  Sub 72
# 135     Age_A  Female  Neck_L  Sub 72
# 136     Age_A  Female  Neck_L  Sub 72
# 137     Age_A  Female  Neck_R  Sub 73
# 138     Age_A  Female  Neck_R  Sub 73
# 139     Age_A  Female  Neck_R  Sub 73
# 140     Age_A  Female  Neck_L  Sub 73
# 141     Age_A  Female  Neck_L  Sub 73
# 142     Age_A  Female  Neck_L  Sub 73
# 143     Age_A  Female  Neck_R  Sub 74
# 144     Age_A  Female  Neck_R  Sub 74
# 145     Age_A  Female  Neck_R  Sub 74
# 146     Age_A  Female  Neck_L  Sub 74
# 147     Age_A  Female  Neck_L  Sub 74
# 148     Age_A  Female  Neck_L  Sub 74
# 149     Age_A  Female  Neck_R   Sub 8
# 150     Age_A  Female  Neck_R   Sub 8
# 151     Age_A  Female  Neck_R   Sub 8
# 152     Age_A  Female  Neck_L   Sub 8
# 153     Age_A  Female  Neck_L   Sub 8
# 154     Age_A  Female  Neck_L   Sub 8
#
#                                                   File  Max fft  Min fft
# 0    ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A...    1.000      0.0
# 1    ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A...    1.000      0.0
# 2    ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A...    1.000      0.0
# 3    ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A...    1.000      0.0
# 4    ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A...    1.000      0.0
# 5    ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A...    1.000      0.0
# 6    ../datasets/Age_A/Age_A_Male/Sub 38/38Neck_R_A...    1.000      0.0
# 7    ../datasets/Age_A/Age_A_Male/Sub 38/38Neck_R_A...    1.000      0.0
# 8    ../datasets/Age_A/Age_A_Male/Sub 38/38Neck_R_A...    1.000      0.0
# 9    ../datasets/Age_A/Age_A_Male/Sub 38/38Neck_L_A...    0.995      0.0
# 10   ../datasets/Age_A/Age_A_Male/Sub 38/38Neck_L_A...    1.000      0.0
# 11   ../datasets/Age_A/Age_A_Male/Sub 38/38Neck_L_A...    1.000      0.0
# 12    ../datasets/Age_A/Age_A_Male/Sub 42/42_L_A_1.mat    1.000      0.0
# 13   ../datasets/Age_A/Age_A_Male/Sub 43/43Neck_R_A...    1.000      0.0
# 14   ../datasets/Age_A/Age_A_Male/Sub 43/43Neck_L_A...    0.835      0.0
# 15   ../datasets/Age_A/Age_A_Male/Sub 45/45Neck_R_A...    0.652      0.0
# 16   ../datasets/Age_A/Age_A_Male/Sub 45/45Neck_R_A...    0.562      0.0
# 17   ../datasets/Age_A/Age_A_Male/Sub 45/45Neck_R_A...    0.533      0.0
# 18   ../datasets/Age_A/Age_A_Male/Sub 45/45Neck_L_A...    0.580      0.0
# 19   ../datasets/Age_A/Age_A_Male/Sub 45/45Neck_L_A...    0.581      0.0
# 20   ../datasets/Age_A/Age_A_Male/Sub 45/45Neck_L_A...    0.648      0.0
# 21   ../datasets/Age_A/Age_A_Male/Sub 65/65NECK_R_A...    0.580      0.0
# 22   ../datasets/Age_A/Age_A_Male/Sub 65/65NECK_R_A...    0.596      0.0
# 23   ../datasets/Age_A/Age_A_Male/Sub 65/65NECK_R_A...    0.938      0.0
# 24   ../datasets/Age_A/Age_A_Male/Sub 65/65NECK_L_A...    0.599      0.0
# 25   ../datasets/Age_A/Age_A_Male/Sub 65/65NECK_L_A...    0.614      0.0
# 26   ../datasets/Age_A/Age_A_Male/Sub 65/65NECK_L_A...    0.616      0.0
# 27   ../datasets/Age_A/Age_A_Male/Sub 67/67Neck_R_A...    0.569      0.0
# 28   ../datasets/Age_A/Age_A_Male/Sub 67/67Neck_R_A...    0.589      0.0
# 29   ../datasets/Age_A/Age_A_Male/Sub 67/67Neck_R_A...    0.566      0.0
# ..                                                 ...      ...      ...
# 125  ../datasets/Age_A/Age_A_Female/Sub 70/70_neck_...    0.578      0.0
# 126  ../datasets/Age_A/Age_A_Female/Sub 70/70_neck_...    0.525      0.0
# 127  ../datasets/Age_A/Age_A_Female/Sub 70/70_neck_...    0.601      0.0
# 128  ../datasets/Age_A/Age_A_Female/Sub 70/70_neck_...    0.707      0.0
# 129  ../datasets/Age_A/Age_A_Female/Sub 70/70_neck_...    0.546      0.0
# 130  ../datasets/Age_A/Age_A_Female/Sub 70/70_neck_...    0.629      0.0
# 131  ../datasets/Age_A/Age_A_Female/Sub 72/72Neck_R...    0.754      0.0
# 132  ../datasets/Age_A/Age_A_Female/Sub 72/72Neck_R...    0.599      0.0
# 133  ../datasets/Age_A/Age_A_Female/Sub 72/72Neck_R...    0.577      0.0
# 134  ../datasets/Age_A/Age_A_Female/Sub 72/72Neck_L...    0.606      0.0
# 135  ../datasets/Age_A/Age_A_Female/Sub 72/72Neck_L...    0.565      0.0
# 136  ../datasets/Age_A/Age_A_Female/Sub 72/72Neck_L...    0.723      0.0
# 137  ../datasets/Age_A/Age_A_Female/Sub 73/73Neck_R...    0.615      0.0
# 138  ../datasets/Age_A/Age_A_Female/Sub 73/73Neck_R...    0.601      0.0
# 139  ../datasets/Age_A/Age_A_Female/Sub 73/73Neck_R...    0.566      0.0
# 140  ../datasets/Age_A/Age_A_Female/Sub 73/73Neck_L...    0.586      0.0
# 141  ../datasets/Age_A/Age_A_Female/Sub 73/73Neck_L...    0.642      0.0
# 142  ../datasets/Age_A/Age_A_Female/Sub 73/73Neck_L...    0.594      0.0
# 143  ../datasets/Age_A/Age_A_Female/Sub 74/74Neck_R...    0.591      0.0
# 144  ../datasets/Age_A/Age_A_Female/Sub 74/74Neck_R...    0.568      0.0
# 145  ../datasets/Age_A/Age_A_Female/Sub 74/74Neck_R...    0.578      0.0
# 146  ../datasets/Age_A/Age_A_Female/Sub 74/74Neck_L...    0.627      0.0
# 147  ../datasets/Age_A/Age_A_Female/Sub 74/74Neck_L...    0.561      0.0
# 148  ../datasets/Age_A/Age_A_Female/Sub 74/74Neck_L...    0.556      0.0
# 149  ../datasets/Age_A/Age_A_Female/Sub 8/8Neck_R_A...    1.000      0.0
# 150  ../datasets/Age_A/Age_A_Female/Sub 8/8Neck_R_A...    1.000      0.0
# 151  ../datasets/Age_A/Age_A_Female/Sub 8/8Neck_R_A...    1.000      0.0
# 152  ../datasets/Age_A/Age_A_Female/Sub 8/8Neck_L_A...    1.000      0.0
# 153  ../datasets/Age_A/Age_A_Female/Sub 8/8Neck_L_A...    1.000      0.0
# 154  ../datasets/Age_A/Age_A_Female/Sub 8/8Neck_L_A...    1.000      0.0
#
# [155 rows x 7 columns]
