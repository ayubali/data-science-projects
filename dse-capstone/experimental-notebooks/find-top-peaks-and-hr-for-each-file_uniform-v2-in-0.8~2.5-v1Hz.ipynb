# %%
import scipy.io as sio
from scipy.fft import fft
import os,glob
import math
import numpy as np
import pandas as pd
import os,glob
import pyexcel
import signal_utll

# %%
df = pd.read_csv('../datasets/laser_ds.csv')
df.head()
# Out:
#   Age Group   Sex    Side     Sub  \
# 0     Age_A  Male  Neck_R  Sub 36
# 1     Age_A  Male  Neck_R  Sub 36
# 2     Age_A  Male  Neck_R  Sub 36
# 3     Age_A  Male  Neck_L  Sub 36
# 4     Age_A  Male  Neck_L  Sub 36
#
#                                                 File
# 0  ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A...
# 1  ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A...
# 2  ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A...
# 3  ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A...
# 4  ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A...

# %%
Hz_Lthr, Hz_Hthr, ROI_Hz_Lthr, ROI_Hz_Hthr ,low_weight, high_weight, high_weight2, no_peaks= 0.4, 3.5, 0.8, 2.5, 0.01, 0.07, 0.08, 5

top_peaks_array=[]
secs=60 # 1 mins

for i, row in df.iterrows():
    X, Y, peaks_idx = signal_utll.find_top_peaks_with_uniform_weight_v2(row['File'], Hz_Lthr, Hz_Hthr, 
                                                                     ROI_Hz_Lthr, ROI_Hz_Hthr, 
                                                                     low_weight, high_weight, high_weight2, no_peaks)
    peaks_hr = [round(X[peak]*secs) for peak in peaks_idx]
    top_peaks_array.append(peaks_hr)

df['Peaks_Hr'] = top_peaks_array

# %%
df.head()
# Out:
#   Age Group   Sex    Side     Sub  \
# 0     Age_A  Male  Neck_R  Sub 36
# 1     Age_A  Male  Neck_R  Sub 36
# 2     Age_A  Male  Neck_R  Sub 36
# 3     Age_A  Male  Neck_L  Sub 36
# 4     Age_A  Male  Neck_L  Sub 36
#
#                                                 File  \
# 0  ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A...
# 1  ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A...
# 2  ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_A...
# 3  ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A...
# 4  ../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_A...
#
#                             Peaks_Hr
# 0    [51.0, 54.0, 60.0, 62.0, 108.0]
# 1  [74.0, 80.0, 113.0, 132.0, 143.0]
# 2   [72.0, 93.0, 99.0, 101.0, 137.0]
# 3   [67.0, 94.0, 96.0, 148.0, 150.0]
# 4  [61.0, 68.0, 100.0, 124.0, 149.0]

# %%
grouped_df = df.groupby(by=["Age Group","Sex","Sub"])

# %%
rows = []
for name, group in grouped_df: 
    n_row = list(name)
    gr_peaks = []
    for i, row in group.iterrows():
            gr_peaks.append(row['Peaks_Hr'])
    gr_peaks_list = [item for sublist in gr_peaks for item in sublist]
    #max_peak_cluster_center = signal_utll.do_clusters_and_find_max_center(gr_peaks_list, 5)
    
    n_row.append(round(max_peak_cluster_center, 2))
    rows.append(n_row)
    

df_Peaks= pd.DataFrame(rows);
df_Peaks
# Out:
#         0       1       2       3
# 0   Age_A  Female  Sub 25  120.50
# 1   Age_A  Female  Sub 28  108.75
# 2   Age_A  Female  Sub 32  102.00
# 3   Age_A  Female  Sub 35   92.40
# 4   Age_A  Female  Sub 44  130.62
# 5   Age_A  Female  Sub 46  100.11
# 6   Age_A  Female  Sub 63  130.00
# 7   Age_A  Female  Sub 64  108.38
# 8   Age_A  Female  Sub 66   99.14
# 9   Age_A  Female  Sub 69  140.29
# 10  Age_A  Female  Sub 70   78.62
# 11  Age_A  Female  Sub 72   86.00
# 12  Age_A  Female  Sub 73  100.57
# 13  Age_A  Female  Sub 74  137.12
# 14  Age_A  Female   Sub 8  136.33
# 15  Age_A  Female  sub 59  100.20
# 16  Age_A    Male  Sub 36  142.00
# 17  Age_A    Male  Sub 38  107.00
# 18  Age_A    Male  Sub 42   84.40
# 19  Age_A    Male  Sub 43   74.50
# 20  Age_A    Male  Sub 45   80.62
# 21  Age_A    Male  Sub 65  118.00
# 22  Age_A    Male  Sub 67  137.12
# 23  Age_A    Male  Sub 68   55.43
# 24  Age_A    Male  Sub 70   78.62
# 25  Age_A    Male  Sub 73  100.57
# 26  Age_A    Male  Sub 74  137.12
# 27  Age_A    Male  Sub 76   87.50
# 28  Age_A    Male  Sub 77   76.29
# 29  Age_B  Female  Sub 21   94.50
# 30  Age_B  Female  Sub 22   77.55
# 31  Age_B  Female  Sub 27  116.60
# 32  Age_B  Female  Sub 61   54.38
# 33  Age_B    Male  Sub 23  123.25
# 34  Age_B    Male   Sub 4   54.33
# 35  Age_C  Female   Sub 1  120.67
# 36  Age_C  Female  Sub 47  133.44
# 37  Age_C  Female  Sub 60   75.09
# 38  Age_C    Male  Sub 41  118.12
# 39  Age_C    Male  Sub 66   89.00

# %%
df_Peaks.columns = ["Age Group","Sex","Sub", "Heart Beat 0.8~2.5hz"]
df_Peaks.head()
# Out:
#   Age Group     Sex     Sub  Heart Beat 0.8~2.5hz
# 0     Age_A  Female  Sub 25                 53.92
# 1     Age_A  Female  Sub 28                 57.21
# 2     Age_A  Female  Sub 32                 60.75
# 3     Age_A  Female  Sub 35                 54.06
# 4     Age_A  Female  Sub 44                 51.90

# %%
df_Peaks.to_csv('../datasets/ds_hr_0.8_2.5hz-v1.csv',index = False, header=True)

# %%
#https://www.medicinenet.com/what_is_a_good_heart_rate_for_my_age/article.htm
