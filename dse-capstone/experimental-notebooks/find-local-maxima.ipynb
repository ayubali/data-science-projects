# %%
import numpy as np
from scipy.signal import argrelextrema

x = np.random.random(50)

# for local maxima
localMaxima= argrelextrema(x, np.greater)

# for local minima
localMinima = argrelextrema(x, np.less)

# %%
x
# Out:
# array([0.98919917, 0.36706921, 0.2742281 , 0.05373742, 0.30129113,
#        0.13156469, 0.65942822, 0.47129827, 0.79881741, 0.1374674 ,
#        0.86007806, 0.69559063, 0.46558825, 0.39352449, 0.13796772,
#        0.09018673, 0.05414119, 0.1521646 , 0.1924951 , 0.98149967,
#        0.01445209, 0.2043059 , 0.90826611, 0.47157892, 0.20207702,
#        0.73915461, 0.5793955 , 0.6427332 , 0.1863072 , 0.05224404,
#        0.50519333, 0.39269657, 0.46718339, 0.78392852, 0.06951784,
#        0.71235594, 0.99729611, 0.49433649, 0.63630062, 0.80687309,
#        0.51374533, 0.90657804, 0.70990796, 0.22236629, 0.04973409,
#        0.5986936 , 0.85320038, 0.21605993, 0.14095418, 0.09573105])

# %%
localMaxima
# Out:
# (array([ 4,  6,  8, 10, 19, 22, 25, 27, 30, 33, 36, 39, 41, 46]),)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  

plt.plot(x)
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.misc import electrocardiogram
from scipy.signal import find_peaks
import numpy as np

x = electrocardiogram()[1000:6000]
peaks, _ = find_peaks(x, height=0)
plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.plot(np.zeros_like(x), "--", color="gray")
plt.show()

# %%
peaks
# Out:
# array([  12,   29,  130,  265,  317,  449,  501,  548,  553,  563,  582,
#         587,  691,  880, 1065, 1251, 1325, 1331, 1336, 1386, 1431, 1464,
#        1471, 1475, 1481, 1489, 1494, 1496, 1500, 1507, 1512, 1520, 1524,
#        1529, 1535, 1541, 1554, 1560, 1566, 1571, 1578, 1584, 1590, 1595,
#        1608, 1620, 1625, 1631, 1637, 1643, 1651, 1656, 1661, 1668, 1675,
#        1686, 1692, 1703, 1709, 1717, 1722, 1729, 1731, 1733, 1738, 1747,
#        1758, 1763, 1779, 1788, 1793, 1799, 1808, 1811, 1813, 1818, 1825,
#        1836, 1849, 1856, 1860, 1863, 1867, 1871, 1882, 1888, 1895, 1908,
#        1914, 1927, 1938, 1956, 1967, 1973, 1980, 1987, 1992, 1998, 2005,
#        2009, 2016, 2022, 2029, 2034, 2040, 2044, 2051, 2064, 2070, 2077,
#        2082, 2094, 2099, 2105, 2111, 2125, 2136, 2144, 2147, 2154, 2161,
#        2167, 2171, 2179, 2186, 2188, 2190, 2201, 2206, 2210, 2220, 2236,
#        2244, 2249, 2255, 2267, 2273, 2278, 2292, 2347, 2353, 2357, 2370,
#        2377, 2388, 2406, 2412, 2417, 2456, 2614, 2776, 2948, 3129, 3310,
#        3482, 3652, 3812, 3984, 4157, 4280, 4323, 4374, 4381, 4386, 4393,
#        4399, 4411, 4415, 4422, 4428, 4450, 4454, 4470, 4476, 4481, 4496,
#        4505, 4510, 4512, 4517, 4522, 4528, 4530, 4536, 4549, 4555, 4561,
#        4567, 4573, 4579, 4585, 4588, 4591, 4596, 4602, 4608, 4615, 4621,
#        4633, 4638, 4644, 4650, 4656, 4663, 4674, 4686, 4693, 4704, 4711,
#        4713, 4717, 4722, 4727, 4742, 4754, 4764, 4771, 4777, 4781, 4788,
#        4795, 4801, 4808, 4817, 4824, 4856, 4871, 4878, 4883, 4890, 4902,
#        4907, 4914, 4920, 4927, 4933, 4951, 4957, 4962, 4969, 4974, 4981,
#        4987, 4993])
