# %%
import scipy.io as sio
from scipy.fft import fft
import os,glob
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mat4py import loadmat

# %%
import scipy.io as sio

def wfft_hz(filename, Hz_Lthr, Hz_Hthr):
    '"Lthr: lower threshold; Hthr: high threshold"'
    data = loadmat(filename)
    fft_data = fft(data['data'])
    NFFT = math.floor(len(data['data'])/2)+1
    fft_data = abs(fft_data[1:NFFT])
    f = data['Fs']/2 * np.linspace(0, 1, NFFT)
    idx = [i for i, e in enumerate(f) if e>= Hz_Lthr and e <= Hz_Hthr ] 
    X=f[idx]
    y=fft_data[idx]
    return X, y

# %%
Hz_Lthr, Hz_Hthr =0.8, 2.5 
file = '../datasets/Age_A/Age_A_Female/Sub 25/25Neck_L_A_1.mat'
[X,y] =  wfft_hz('../datasets/Age_A/Age_A_Female/Sub 25/25Neck_L_A_1.mat', Hz_Lthr, Hz_Hthr)
plt.figure(figsize=(12, 6), dpi=80)
plt.plot(X, y)
plt.ylabel('FFT magnitude')
#plt.text(6, 0.05, "Min:"+str(min(y))+"  Max:"+str(max(y))  ,fontsize=16, bbox=dict(facecolor='red', alpha=0.5))
plt.show()
print("Min:"+str(min(y))+"  Max:"+str(max(y)))
# Out:
# Min:[0.02929688]  Max:[0.03961182]

# %%
file = '../datasets/Age_A/Age_A_Male/Sub 73/73Neck_R_A_2 .mat'
[X,y] =  wfft_hz(file,Hz_Lthr, Hz_Hthr)

plt.figure(figsize=(12, 6), dpi=80)
plt.plot(X, y)
plt.ylabel('FFT magnitude')
#plt.text(6, 0.3, "Min:"+str(min(y))+"  Max:"+str(max(y))  ,fontsize=16, bbox=dict(facecolor='red', alpha=0.5))
plt.show() 
print("Min:"+str(min(y))+"  Max:"+str(max(y)))
# Out:
# Min:[0.28753662]  Max:[0.30224609]

# %%
file = '../datasets/Age_A/Age_A_Female/Sub 28/28Neck_L_A_1.mat'
[X,y] =  wfft_hz(file,Hz_Lthr, Hz_Hthr)

plt.figure(figsize=(12, 6), dpi=80)
plt.plot(X, y)
plt.ylabel('FFT magnitude')
#plt.text(6, 0.3, "Min:"+str(min(y))+"  Max:"+str(max(y))  ,fontsize=16, bbox=dict(facecolor='red', alpha=0.5))
plt.show()
print("Min:"+str(min(y))+"  Max:"+str(max(y)))
# Out:
# Min:[0.03909302]  Max:[0.19171143]

# %%
file = '../datasets/Age_A/Age_A_Female/Sub 28/28Neck_L_avg.mat'
[X,y] =  wfft_hz(file, Hz_Lthr, Hz_Hthr)
plt.figure(figsize=(16, 6), dpi=80)
plt.plot(X, y)
plt.ylabel('FFT magnitude')
#plt.text(6, 0.3, "Min:"+str(min(y))+"  Max:"+str(max(y))  ,fontsize=16, bbox=dict(facecolor='red', alpha=0.5))
plt.show()
print("Min:"+str(min(y))+"  Max:"+str(max(y)))
# Out:
# Min:[0.045615]  Max:[0.10391552]

# %%
file = '../datasets/Age_A/Age_A_Female/Sub 28/28Neck_R_avg.mat'
[X,y] =  wfft_hz(file,Hz_Lthr, Hz_Hthr)
plt.figure(figsize=(16, 6), dpi=80)
plt.plot(X, y, )
plt.ylabel('FFT magnitude')
#plt.text(6, 0.3, "Min:"+str(min(y))+"  Max:"+str(max(y))  ,fontsize=16, bbox=dict(facecolor='red', alpha=0.5))
plt.show()
print("Min:"+str(min(y))+"  Max:"+str(max(y)))
# Out:
# Min:[0.17359394]  Max:[0.17798682]

# %%
file = '../datasets/Age_A/Age_A_Male/Sub 36/36Neck_L_avg.mat'
[X,y] =  wfft_hz(file,Hz_Lthr, Hz_Hthr)

plt.figure(figsize=(12, 6), dpi=80)
plt.plot(X, y)
plt.ylabel('FFT magnitude')
#plt.text(6, 0.3, "Min:"+str(min(y))+"  Max:"+str(max(y))  ,fontsize=16, bbox=dict(facecolor='red', alpha=0.5))
plt.show()
print("Min:"+str(min(y))+"  Max:"+str(max(y)))
# Out:
# Min:[0.18137324]  Max:[0.24986631]

# %%
file = '../datasets/Age_A/Age_A_Male/Sub 36/36Neck_R_avg.mat'
[X,y] =  wfft_hz(file,Hz_Lthr, Hz_Hthr)

plt.figure(figsize=(12, 6), dpi=80)
plt.plot(X, y)
plt.ylabel('FFT magnitude')
#plt.text(6, 0.3, "Min:"+str(min(y))+"  Max:"+str(max(y))  ,fontsize=16, bbox=dict(facecolor='red', alpha=0.5))
plt.show()
print("Min:"+str(min(y))+"  Max:"+str(max(y)))
# Out:
# Min:[0.09041617]  Max:[0.13690603]

# %%
from scipy.signal import find_peaks

# %%
[X,y] =  wfft_hz(file,Hz_Lthr, Hz_Hthr)
peaks, _ = find_peaks(X, height=10)

# %%
round
# Out:
# array([], dtype=int64)

# %%
_
# Out:
# {'peak_heights': array([], dtype=float64)}

# %%
V= [ round(v,6) for v in X ]

# %%
peaks, _ = find_peaks(V,distance=150)

# %%
peaks
# Out:
# array([], dtype=int64)
